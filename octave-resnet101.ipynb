# %%
from keras.layers import Conv2D, AveragePooling2D, UpSampling2D
from keras.layers import add


def initial_octconv(ip, filters, kernel_size=(3, 3), strides=(1, 1),
                    alpha=0.5, padding='same', dilation=None, bias=False):
    """
    Initializes the Octave Convolution architecture.

    Accepts a single input tensor, and returns a pair of tensors.
    The first tensor is the high frequency pathway.
    The second tensor is the low frequency pathway.

    # Arguments:
        ip: keras tensor.
        filters: number of filters in conv layer.
        kernel_size: conv kernel size.
        strides: strides of the conv.
        alpha: float between [0, 1]. Defines the ratio of filters
            allocated to the high frequency and low frequency
            branches of the octave conv.
        padding: padding mode.
        dilation: dilation conv kernel.
        bias: bool, whether to use bias or not.

    # Returns:
        a pair of tensors:
            - x_high: high frequency pathway.
            - x_low: low frequency pathway.
    """
    if dilation is None:
        dilation = (1, 1)

    high_low_filters = int(alpha * filters)
    high_high_filters = filters - high_low_filters

    if strides[0] > 1:
        ip = AveragePooling2D()(ip)

    # High path
    x_high = Conv2D(high_high_filters, kernel_size, padding=padding,
                    dilation_rate=dilation, use_bias=bias,
                    kernel_initializer='he_normal')(ip)

    # Low path
    x_high_low = AveragePooling2D(pool_size=(2, 2))(ip)
    x_low = Conv2D(high_low_filters, kernel_size, padding=padding,
                   dilation_rate=dilation, use_bias=bias,
                   kernel_initializer='he_normal')(x_high_low)

    return x_high, x_low


def final_octconv(ip_high, ip_low, filters, kernel_size=(3, 3), strides=(1, 1),
                  padding='same', dilation=None, bias=False):
    """
    Ends the Octave Convolution architecture.

    Accepts two input tensors, and returns a single output tensor.
    The first input tensor is the high frequency pathway.
    The second input tensor is the low frequency pathway.

    # Arguments:
        ip_high: keras tensor.
        ip_low: keras tensor.
        filters: number of filters in conv layer.
        kernel_size: conv kernel size.
        strides: strides of the conv.
        padding: padding mode.
        dilation: dilation conv kernel.
        bias: bool, whether to use bias or not.

    # Returns:
        a single Keras tensor:
            - x_high: The merged high frequency pathway.
    """
    if dilation is None:
        dilation = (1, 1)

    if strides[0] > 1:
        avg_pool = AveragePooling2D(pool_size=(2, 2))

        ip_high = avg_pool(ip_high)
        ip_low = avg_pool(ip_low)

    # High path
    x_high_high = Conv2D(filters, kernel_size, padding=padding,
                         dilation_rate=dilation, use_bias=bias,
                         kernel_initializer='he_normal')(ip_high)

    # Low path
    x_low_high = Conv2D(filters, kernel_size, padding=padding,
                        dilation_rate=dilation, use_bias=bias,
                        kernel_initializer='he_normal')(ip_low)

    x_low_high = UpSampling2D(interpolation='nearest')(x_low_high)

    # Merge paths
    x = add([x_high_high, x_low_high])

    return x


def octconv_block(ip_high, ip_low, filters, kernel_size=(3, 3), strides=(1, 1),
                  alpha=0.5, padding='same', dilation=None, bias=False):
    """
    Constructs an Octave Convolution block.

    Accepts a pair of input tensors, and returns a pair of tensors.
    The first tensor is the high frequency pathway for both ip/op.
    The second tensor is the low frequency pathway for both ip/op.

    # Arguments:
        ip_high: keras tensor.
        ip_low: keras tensor.
        filters: number of filters in conv layer.
        kernel_size: conv kernel size.
        strides: strides of the conv.
        alpha: float between [0, 1]. Defines the ratio of filters
            allocated to the high frequency and low frequency
            branches of the octave conv.
        padding: padding mode.
        dilation: dilation conv kernel.
        bias: bool, whether to use bias or not.

    # Returns:
        a pair of tensors:
            - x_high: high frequency pathway.
            - x_low: low frequency pathway.
    """
    if dilation is None:
        dilation = (1, 1)

    low_low_filters = high_low_filters = int(alpha * filters)
    high_high_filters = low_high_filters = filters - low_low_filters

    avg_pool = AveragePooling2D(pool_size=(2, 2))

    if strides[0] > 1:
        ip_high = avg_pool(ip_high)
        ip_low = avg_pool(ip_low)

    # High path
    x_high_high = Conv2D(high_high_filters, kernel_size, padding=padding,
                         dilation_rate=dilation, use_bias=bias,
                         kernel_initializer='he_normal')(ip_high)

    x_low_high = Conv2D(low_high_filters, kernel_size, padding=padding,
                        dilation_rate=dilation, use_bias=bias,
                        kernel_initializer='he_normal')(ip_low)
    x_low_high = UpSampling2D(interpolation='nearest')(x_low_high)

    # Low path
    x_low_low = Conv2D(low_low_filters, kernel_size, padding=padding,
                       dilation_rate=dilation, use_bias=bias,
                       kernel_initializer='he_normal')(ip_low)

    x_high_low = avg_pool(ip_high)
    x_high_low = Conv2D(high_low_filters, kernel_size, padding=padding,
                        dilation_rate=dilation, use_bias=bias,
                        kernel_initializer='he_normal')(x_high_low)

    # Merge paths
    x_high = add([x_high_high, x_low_high])
    x_low = add([x_low_low, x_high_low])

    return x_high, x_low


if __name__ == '__main__':

    visualize_model = True

    from keras.models import Model
    from keras.layers import Input

    ip = Input(shape=(32, 32, 3))

    xh, xl = initial_octconv(ip, filters=48)

    xh, xl = octconv_block(xh, xl, filters=64)
    xh, xl = octconv_block(xh, xl, filters=96, strides=(2, 2))

    x = final_octconv(xh, xl, filters=10)

    model = Model(ip, x)
    model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 16, 16, 3) │          0 │ input_layer_1[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │        648 │ average_pooling2… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │        648 │ input_layer_1[0]… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │      6,912 │ conv2d_13[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │      6,912 │ conv2d_12[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 32, 32,    │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 16, 16,    │          0 │ conv2d_12[0][0]   │
# │ (AveragePooling2D)  │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 32, 32,    │          0 │ conv2d_14[0][0],  │
# │                     │ 32)               │            │ up_sampling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 16, 16,    │      6,912 │ conv2d_13[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 16, 16,    │      6,912 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 8, 8, 32)  │          0 │ add_5[0][0],      │
# │ (AveragePooling2D)  │                   │            │ add_6[0][0],      │
# │                     │                   │            │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 16, 16,    │          0 │ conv2d_16[0][0],  │
# │                     │ 32)               │            │ conv2d_17[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 8, 8, 48)  │     13,824 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 8, 8, 48)  │     13,824 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 8, 8, 48)  │     13,824 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 16, 16,    │     13,824 │ average_pooling2… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 16, 16,    │          0 │ conv2d_19[0][0]   │
# │ (UpSampling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 8, 8, 48)  │          0 │ conv2d_20[0][0],  │
# │                     │                   │            │ conv2d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 16,    │          0 │ conv2d_18[0][0],  │
# │                     │ 48)               │            │ up_sampling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 10)  │      4,320 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 16, 16,    │      4,320 │ add_7[0][0]       │
# │                     │ 10)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 16, 16,    │          0 │ conv2d_23[0][0]   │
# │ (UpSampling2D)      │ 10)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 16, 16,    │          0 │ conv2d_22[0][0],  │
# │                     │ 10)               │            │ up_sampling2d_5[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 92,880 (362.81 KB)
#  Trainable params: 92,880 (362.81 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'



from keras.layers import ReLU, BatchNormalization
from keras import backend as K



def initial_oct_conv_bn_relu(ip, filters, kernel_size=(3, 3), strides=(1, 1),
                             alpha=0.5, padding='same', dilation=None, bias=False,
                             activation=True):

    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x_high, x_low = initial_octconv(ip, filters, kernel_size, strides, alpha,
                                    padding, dilation, bias)

    relu = ReLU()
    x_high = BatchNormalization(axis=channel_axis)(x_high)
    if activation:
        x_high = relu(x_high)

    x_low = BatchNormalization(axis=channel_axis)(x_low)
    if activation:
        x_low = relu(x_low)

    return x_high, x_low


def final_oct_conv_bn_relu(ip_high, ip_low, filters, kernel_size=(3, 3), strides=(1, 1),
                           padding='same', dilation=None, bias=False, activation=True):

    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x = final_octconv(ip_high, ip_low, filters, kernel_size, strides,
                      padding, dilation, bias)

    x = BatchNormalization(axis=channel_axis)(x)
    if activation:
        x = ReLU()(x)

    return x


def oct_conv_bn_relu(ip_high, ip_low, filters, kernel_size=(3, 3), strides=(1, 1),
                     alpha=0.5, padding='same', dilation=None, bias=False, activation=True):

    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x_high, x_low = octconv_block(ip_high, ip_low, filters, kernel_size, strides, alpha,
                                  padding, dilation, bias)

    relu = ReLU()
    x_high = BatchNormalization(axis=channel_axis)(x_high)
    if activation:
        x_high = relu(x_high)

    x_low = BatchNormalization(axis=channel_axis)(x_low)
    if activation:
        x_low = relu(x_low)

    return x_high, x_low

# %%
import os
from keras.layers import BatchNormalization
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import Input
from keras.layers import MaxPool2D
from keras.layers import ReLU
from keras.layers import add
from keras.models import Model
from keras.utils import get_source_inputs

from keras import backend as K
from keras_applications.imagenet_utils import _obtain_input_shape



def _conv_block(ip, filters, kernel_size=(3, 3), strides=(1, 1),
                padding='same', bias=False):
    x = Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=bias,
               kernel_initializer='he_normal')(ip)

    return x


def _conv_bn_relu(ip, filters, kernel_size=(3, 3), strides=(1, 1),
                  padding='same', bias=False, activation=True):

    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x = _conv_block(ip, filters, kernel_size, strides, padding, bias)
    x = BatchNormalization(axis=channel_axis)(x)
    if activation:
        x = ReLU()(x)

    return x


def _octresnet_bottleneck_block(ip, filters, alpha=0.5, strides=(1, 1),
                                downsample_shortcut=False, first_block=False,
                                expansion=4):

    if first_block:
        x_high_res, x_low_res = initial_oct_conv_bn_relu(ip, filters, kernel_size=(1, 1),
                                                         alpha=alpha)

        x_high, x_low = oct_conv_bn_relu(x_high_res, x_low_res, filters, kernel_size=(3, 3),
                                         strides=strides, alpha=alpha)

    else:
        x_high_res, x_low_res = ip
        x_high, x_low = oct_conv_bn_relu(x_high_res, x_low_res, filters, kernel_size=(1, 1),
                                         alpha=alpha)

        x_high, x_low = oct_conv_bn_relu(x_high, x_low, filters, kernel_size=(3, 3),
                                         strides=strides, alpha=alpha)

    final_out_filters = int(filters * expansion)
    x_high, x_low = oct_conv_bn_relu(x_high, x_low, filters=final_out_filters,
                                     kernel_size=(1, 1), alpha=alpha, activation=False)

    if downsample_shortcut:
        x_high_res, x_low_res = oct_conv_bn_relu(x_high_res, x_low_res,
                                                 final_out_filters, kernel_size=(1, 1),
                                                 strides=strides, alpha=alpha,
                                                 activation=False)

    x_high = add([x_high, x_high_res])
    x_low = add([x_low, x_low_res])

    x_high = ReLU()(x_high)
    x_low = ReLU()(x_low)

    return x_high, x_low


def _octresnet_final_bottleneck_block(ip, filters, alpha=0.5, strides=(1, 1),
                                      downsample_shortcut=False,
                                      expansion=4):

    x_high_res, x_low_res = ip

    x_high, x_low = oct_conv_bn_relu(x_high_res, x_low_res, filters, kernel_size=(1, 1),
                                     alpha=alpha)

    x_high, x_low = oct_conv_bn_relu(x_high, x_low, filters, kernel_size=(3, 3),
                                     strides=strides, alpha=alpha)

    final_filters = int(filters * expansion)
    x_high = final_oct_conv_bn_relu(x_high, x_low, final_filters, kernel_size=(1, 1),
                                    activation=False)

    if downsample_shortcut:
        x_high_res = final_oct_conv_bn_relu(x_high_res, x_low_res, final_filters, kernel_size=(1, 1),
                                            strides=strides, activation=False)

    x = add([x_high, x_high_res])
    x = ReLU()(x)

    return x


def _bottleneck_original(ip, filters, strides=(1, 1), downsample_shortcut=False,
                         expansion=4):

    final_filters = int(filters * expansion)

    shortcut = ip

    x = _conv_bn_relu(ip, filters, kernel_size=(1, 1))
    x = _conv_bn_relu(x, filters, kernel_size=(3, 3), strides=strides)
    x = _conv_bn_relu(x, final_filters, kernel_size=(1, 1), activation=False)

    if downsample_shortcut:
        shortcut = _conv_block(shortcut, final_filters, kernel_size=(1, 1),
                               strides=strides)

    x = add([x, shortcut])
    x = ReLU()(x)

    return x


def OctaveResNet(layers,
                 include_top=True,
                 weights=None,
                 input_tensor=None,
                 input_shape=None,
                 pooling=None,
                 classes=1000,
                 alpha=0.5,
                 expansion=1,
                 initial_filters=64,
                 initial_strides=False,
                 **kwargs):
    """ Instantiates a Octave ResNet architecture.

    # Arguments
        layers: list of integers defining the depth of the network and
            the number of octave conv blocks per level of the
            network.
        include_top: whether to include the fully-connected
            layer at the top of the network.
        weights: one of `None` (random initialization),
              'imagenet' (pre-training on ImageNet),
              or the path to the weights file to be loaded.
        input_tensor: optional Keras tensor
            (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: optional shape tuple, only to be specified
            if `include_top` is False (otherwise the input shape
            has to be `(224, 224, 3)` (with `'channels_last'` data format)
            or `(3, 224, 224)` (with `'channels_first'` data format).
            It should have exactly 3 inputs channels,
            and width and height should be no smaller than 32.
            E.g. `(200, 200, 3)` would be one valid value.
        pooling: optional pooling mode for feature extraction
            when `include_top` is `False`.
            - `None` means that the output of the model will be
                the 4D tensor output of the
                last convolutional layer.
            - `avg` means that global average pooling
                will be applied to the output of the
                last convolutional layer, and thus
                the output of the model will be a 2D tensor.
            - `max` means that global max pooling will
                be applied.
        classes: optional number of classes to classify images
            into, only to be specified if `include_top` is True, and
            if no `weights` argument is specified.
        alpha: float between [0, 1]. Defines the ratio of filters
            allocated to the high frequency and low frequency
            branches of the octave conv.
        expansion: int/float. Multiplicative factor to increase the
            number of filters in each octave block.
        initial_filters: number of filters in the first convolution
            layer. Determines how many parameters the network will
            have.
        initial_strides: bool to determine whether to apply a strided
            convolution and max pooling before any octave conv
            block. Set to True for ImageNet models and False for
            CIFAR models.

    # Returns
        A Keras model instance.

    # Raises
        ValueError: in case of invalid argument for `weights`,
            or invalid input shape.
`       ValueError: If `alpha` is < 0 or > 1.
        ValueError: If `layers` is not a list or a tuple
            of integers.
    """

    if not (weights in {'imagenet', None} or os.path.exists(weights)):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization), `imagenet` '
                         '(pre-training on ImageNet), '
                         'or the path to the weights file to be loaded.')

    if weights == 'imagenet' and include_top and classes != 1000:
        raise ValueError('If using `weights` as `"imagenet"` with `include_top`'
                         ' as true, `classes` should be 1000')

    if alpha < 0. or alpha > 1.:
        raise ValueError('`alpha` must be between 0 and 1. Current alpha = '
                         '%f' % alpha)

    if type(layers) not in [list, tuple]:
        raise ValueError('`layers` must be a list/tuple of integers. '
                         'Current layers = ', layers)

    # Force convert all layer values to integers
    layers = [int(x) for x in layers]

    # Determine proper input shape
    input_shape = _obtain_input_shape(input_shape,
                                      default_size=224,
                                      min_size=32,
                                      data_format=K.image_data_format(),
                                      require_flatten=include_top,
                                      weights=weights)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    if initial_strides:
        initial_strides = (2, 2)

    else:
        initial_strides = (1, 1)

    x = _conv_bn_relu(img_input, filters=64, kernel_size=(7, 7), strides=initial_strides)

    if initial_strides:
        x = MaxPool2D((3, 3), strides=(2, 2), padding='same')(x)

    num_filters = initial_filters
    num_blocks = len(layers)

    for i in range(num_blocks - 1):
        for j in range(layers[i]):
            if j == 0:
                strides = (2, 2)
                downsample_shortcut = True

            else:
                strides = (1, 1)
                downsample_shortcut = False

            # first block has no downsample, no shortcut
            if i == 0 and j == 0:
                first_block = True
                strides = (1, 1)
                downsample_shortcut = True

            else:
                first_block = False

            x = _octresnet_bottleneck_block(x, num_filters, alpha, strides, downsample_shortcut,
                                            first_block, expansion)

        # double number of filters per block
        num_filters *= 2

    # final block
    for j in range(layers[-1]):
        if j == 0:
            strides = (2, 2)
            x = _octresnet_final_bottleneck_block(x, num_filters, alpha, strides,
                                                  downsample_shortcut=True, expansion=expansion)

        else:
            strides = (1, 1)
            x = _bottleneck_original(x, num_filters, strides, expansion=expansion)

    if include_top:
        x = GlobalAveragePooling2D(name='avg_pool')(x)
        x = Dense(classes, activation='softmax', name='fc')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D(name='avg_pool')(x)
        elif pooling == 'max':
            x = GlobalMaxPooling2D(name='max_pool')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:
        inputs = img_input

    model = Model(inputs, x, name='OctaveResNet')

    return model


def OctaveResNet50(include_top=True,
                   weights=None,
                   input_tensor=None,
                   input_shape=None,
                   pooling=None,
                   classes=1000,
                   alpha=0.5,
                   expansion=4,
                   initial_filters=64,
                   initial_strides=True,
                   **kwargs):

    return OctaveResNet([3, 4, 6, 3],
                        include_top,
                        weights,
                        input_tensor,
                        input_shape,
                        pooling,
                        classes,
                        alpha,
                        expansion,
                        initial_filters,
                        initial_strides,
                        **kwargs)


def OctaveResNet101(include_top=True,
                    weights=None,
                    input_tensor=None,
                    input_shape=None,
                    pooling=None,
                    classes=1000,
                    alpha=0.5,
                    expansion=4,
                    initial_filters=64,
                    initial_strides=True,
                    **kwargs):

    return OctaveResNet([3, 4, 23, 3],
                        include_top,
                        weights,
                        input_tensor,
                        input_shape,
                        pooling,
                        classes,
                        alpha,
                        expansion,
                        initial_filters,
                        initial_strides,
                        **kwargs)


def OctaveResNet152(include_top=True,
                    weights=None,
                    input_tensor=None,
                    input_shape=None,
                    pooling=None,
                    classes=1000,
                    alpha=0.5,
                    expansion=4,
                    initial_filters=64,
                    initial_strides=True,
                    **kwargs):

    return OctaveResNet([3, 8, 36, 3],
                        include_top,
                        weights,
                        input_tensor,
                        input_shape,
                        pooling,
                        classes,
                        alpha,
                        expansion,
                        initial_filters,
                        initial_strides,
                        **kwargs)


if __name__ == '__main__':
    model = OctaveResNet50(input_shape=(256, 256, 3), classes=1000,
                           alpha=0.125, expansion=4,
                           initial_filters=64,
                           initial_strides=True)
    model.summary()
# Out:
# Model: "OctaveResNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │      9,408 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ re_lu[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_6 │ (None, 32, 32,    │          0 │ max_pooling2d[0]… │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │      3,584 │ max_pooling2d[0]… │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 32, 8) │        512 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │      4,032 │ re_lu_1[1][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_7 │ (None, 32, 32,    │          0 │ re_lu_1[0][0]     │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │     28,224 │ re_lu_1[0][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 64, 64,    │          0 │ conv2d_28[0][0]   │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 32, 32, 8) │        576 │ re_lu_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 32, 32, 8) │      4,032 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 64, 64,    │          0 │ conv2d_27[0][0],  │
# │                     │ 56)               │            │ up_sampling2d_6[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 32, 32, 8) │          0 │ conv2d_29[0][0],  │
# │                     │                   │            │ conv2d_30[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ add_10[0][0]      │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ add_11[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_2[1][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_1[1][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_8 │ (None, 32, 32,    │          0 │ re_lu_2[0][0]     │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_9 │ (None, 32, 32,    │          0 │ re_lu_1[0][0]     │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_2[0][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 64, 64,    │          0 │ conv2d_32[0][0]   │
# │ (UpSampling2D)      │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_1[0][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 64, 64,    │          0 │ conv2d_36[0][0]   │
# │ (UpSampling2D)      │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 32, 32,    │        256 │ re_lu_2[1][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │      1,792 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │        256 │ re_lu_1[1][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 32, 32,    │      1,792 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 64, 64,    │          0 │ conv2d_31[0][0],  │
# │                     │ 224)              │            │ up_sampling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 64, 64,    │          0 │ conv2d_35[0][0],  │
# │                     │ 224)              │            │ up_sampling2d_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 32, 32,    │          0 │ conv2d_33[0][0],  │
# │                     │ 32)               │            │ conv2d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 32, 32,    │          0 │ conv2d_37[0][0],  │
# │                     │ 32)               │            │ conv2d_38[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        896 │ add_12[0][0]      │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        896 │ add_14[0][0]      │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ add_13[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ add_15[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 224)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ add_16[0][0]      │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ add_17[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_6[0][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (AveragePooling2D)  │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_5[0][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 64, 64,    │          0 │ conv2d_40[0][0]   │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 32, 32, 8) │        256 │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 32, 32, 8) │      1,792 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 64, 64,    │          0 │ conv2d_39[0][0],  │
# │                     │ 56)               │            │ up_sampling2d_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 32, 32, 8) │          0 │ conv2d_41[0][0],  │
# │                     │                   │            │ conv2d_42[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ add_18[0][0]      │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ add_19[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │      4,032 │ re_lu_7[1][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_7[0][0]     │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 64, 64,    │     28,224 │ re_lu_7[0][0]     │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 64, 64,    │          0 │ conv2d_44[0][0]   │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32, 8) │        576 │ re_lu_7[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32, 8) │      4,032 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 64, 64,    │          0 │ conv2d_43[0][0],  │
# │                     │ 56)               │            │ up_sampling2d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 32, 32, 8) │          0 │ conv2d_45[0][0],  │
# │                     │                   │            │ conv2d_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ add_20[0][0]      │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ add_21[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_8[1][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_8[0][0]     │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_8[0][0]     │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 64, 64,    │          0 │ conv2d_48[0][0]   │
# │ (UpSampling2D)      │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 32, 32,    │        256 │ re_lu_8[1][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 32, 32,    │      1,792 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 64, 64,    │          0 │ conv2d_47[0][0],  │
# │                     │ 224)              │            │ up_sampling2d_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 32, 32,    │          0 │ conv2d_49[0][0],  │
# │                     │ 32)               │            │ conv2d_50[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        896 │ add_22[0][0]      │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ add_23[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 224)              │            │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 64, 64,    │          0 │ add_24[0][0]      │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ add_25[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_11[0][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_10[0][0]    │
# │ (AveragePooling2D)  │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_10[0][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 32, 32, 8) │        256 │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 32, 32, 8) │      1,792 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 64, 64,    │          0 │ conv2d_51[0][0],  │
# │                     │ 56)               │            │ up_sampling2d_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 32, 32, 8) │          0 │ conv2d_53[0][0],  │
# │                     │                   │            │ conv2d_54[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ add_26[0][0]      │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ add_27[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 32, 32,    │      4,032 │ re_lu_12[1][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_12[0][0]    │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 64, 64,    │     28,224 │ re_lu_12[0][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 64, 64,    │          0 │ conv2d_56[0][0]   │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 32, 32, 8) │        576 │ re_lu_12[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 32, 32, 8) │      4,032 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 64, 64,    │          0 │ conv2d_55[0][0],  │
# │                     │ 56)               │            │ up_sampling2d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 32, 32, 8) │          0 │ conv2d_57[0][0],  │
# │                     │                   │            │ conv2d_58[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        224 │ add_28[0][0]      │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 8) │         32 │ add_29[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32, 8) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 32, 32,    │      1,792 │ re_lu_13[1][0]    │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │ (AveragePooling2D)  │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 64, 64,    │     12,544 │ re_lu_13[0][0]    │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_14    │ (None, 64, 64,    │          0 │ conv2d_60[0][0]   │
# │ (UpSampling2D)      │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 32, 32,    │        256 │ re_lu_13[1][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 32, 32,    │      1,792 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 64, 64,    │          0 │ conv2d_59[0][0],  │
# │                     │ 224)              │            │ up_sampling2d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 32, 32,    │          0 │ conv2d_61[0][0],  │
# │                     │ 32)               │            │ conv2d_62[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        896 │ add_30[0][0]      │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ add_31[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 224)              │            │ re_lu_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 64, 64,    │          0 │ add_32[0][0]      │
# │                     │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 32, 32,    │          0 │ add_33[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 32, 32,    │      3,584 │ re_lu_16[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │ (AveragePooling2D)  │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 64, 64,    │     25,088 │ re_lu_15[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_15    │ (None, 64, 64,    │          0 │ conv2d_64[0][0]   │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 32, 32,    │        512 │ re_lu_16[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_66 (Conv2D)  │ (None, 32, 32,    │      3,584 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_34 (Add)        │ (None, 64, 64,    │          0 │ conv2d_63[0][0],  │
# │                     │ 112)              │            │ up_sampling2d_15… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_35 (Add)        │ (None, 32, 32,    │          0 │ conv2d_65[0][0],  │
# │                     │ 16)               │            │ conv2d_66[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        448 │ add_34[0][0]      │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ add_35[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_17[0][0],   │
# │ (AveragePooling2D)  │ 112)              │            │ re_lu_17[1][0],   │
# │                     │                   │            │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (None, 16, 16,    │     16,128 │ average_pooling2… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_67 (Conv2D)  │ (None, 32, 32,    │    112,896 │ average_pooling2… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_16    │ (None, 32, 32,    │          0 │ conv2d_68[0][0]   │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, 16, 16,    │      2,304 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 16, 16,    │     16,128 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 32, 32,    │          0 │ conv2d_67[0][0],  │
# │                     │ 112)              │            │ up_sampling2d_16… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 16, 16,    │          0 │ conv2d_69[0][0],  │
# │                     │ 16)               │            │ conv2d_70[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        448 │ add_36[0][0]      │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ add_37[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_15[0][0],   │
# │ (AveragePooling2D)  │ 224)              │            │ re_lu_16[0][0],   │
# │                     │                   │            │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 16, 16,    │      7,168 │ re_lu_18[1][0]    │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 16, 16,    │     14,336 │ average_pooling2… │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_18[0][0]    │
# │ (AveragePooling2D)  │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 32, 32,    │     50,176 │ re_lu_18[0][0]    │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_17    │ (None, 32, 32,    │          0 │ conv2d_72[0][0]   │
# │ (UpSampling2D)      │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 32, 32,    │    100,352 │ average_pooling2… │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 32, 32,    │          0 │ conv2d_76[0][0]   │
# │ (UpSampling2D)      │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 16, 16,    │      1,024 │ re_lu_18[1][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 16, 16,    │      7,168 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 16, 16,    │      2,048 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 16, 16,    │     14,336 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 32, 32,    │          0 │ conv2d_71[0][0],  │
# │                     │ 448)              │            │ up_sampling2d_17… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_40 (Add)        │ (None, 32, 32,    │          0 │ conv2d_75[0][0],  │
# │                     │ 448)              │            │ up_sampling2d_18… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 16, 16,    │          0 │ conv2d_73[0][0],  │
# │                     │ 64)               │            │ conv2d_74[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_41 (Add)        │ (None, 16, 16,    │          0 │ conv2d_77[0][0],  │
# │                     │ 64)               │            │ conv2d_78[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,792 │ add_38[0][0]      │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,792 │ add_40[0][0]      │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ add_39[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ add_41[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_42 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 448)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_43 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 32, 32,    │          0 │ add_42[0][0]      │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 16, 16,    │          0 │ add_43[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 16, 16,    │      7,168 │ re_lu_22[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_21[0][0]    │
# │ (AveragePooling2D)  │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 32, 32,    │     50,176 │ re_lu_21[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 32, 32,    │          0 │ conv2d_80[0][0]   │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 16, 16,    │      1,024 │ re_lu_22[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 16, 16,    │      7,168 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_44 (Add)        │ (None, 32, 32,    │          0 │ conv2d_79[0][0],  │
# │                     │ 112)              │            │ up_sampling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_45 (Add)        │ (None, 16, 16,    │          0 │ conv2d_81[0][0],  │
# │                     │ 16)               │            │ conv2d_82[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        448 │ add_44[0][0]      │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ add_45[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 16, 16,    │     16,128 │ re_lu_23[1][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_23[0][0]    │
# │ (AveragePooling2D)  │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 32, 32,    │    112,896 │ re_lu_23[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_20    │ (None, 32, 32,    │          0 │ conv2d_84[0][0]   │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 16, 16,    │      2,304 │ re_lu_23[1][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 16, 16,    │     16,128 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_46 (Add)        │ (None, 32, 32,    │          0 │ conv2d_83[0][0],  │
# │                     │ 112)              │            │ up_sampling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_47 (Add)        │ (None, 16, 16,    │          0 │ conv2d_85[0][0],  │
# │                     │ 16)               │            │ conv2d_86[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        448 │ add_46[0][0]      │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ add_47[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 16, 16,    │      7,168 │ re_lu_24[1][0]    │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_24[0][0]    │
# │ (AveragePooling2D)  │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 32, 32,    │     50,176 │ re_lu_24[0][0]    │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_21    │ (None, 32, 32,    │          0 │ conv2d_88[0][0]   │
# │ (UpSampling2D)      │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 16, 16,    │      1,024 │ re_lu_24[1][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 16, 16,    │      7,168 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_48 (Add)        │ (None, 32, 32,    │          0 │ conv2d_87[0][0],  │
# │                     │ 448)              │            │ up_sampling2d_21… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_49 (Add)        │ (None, 16, 16,    │          0 │ conv2d_89[0][0],  │
# │                     │ 64)               │            │ conv2d_90[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,792 │ add_48[0][0]      │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ add_49[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_50 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 448)              │            │ re_lu_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_51 (Add)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ re_lu_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 32, 32,    │          0 │ add_50[0][0]      │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 16, 16,    │          0 │ add_51[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 16, 16,    │      7,168 │ re_lu_27[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ re_lu_26[0][0]    │
# │ (AveragePooling2D)  │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 32, 32,    │     50,176 │ re_lu_26[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_22    │ (None, 32, 32,    │          0 │ conv2d_92[0][0]   │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 16, 16,    │      1,024 │ re_lu_27[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 16, 16,    │      7,168 │ average_pooling2… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_52 (Add)        │ (None, 32, 32,    │          0 │ conv2d_91[0][0],  │
# │                     │ 112)              │            │ up_sampling2d_22… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_53 (Add)        │ (None, 16, 16,    │          0 │ conv2d_93[0][0],  │
# │                     │ 16)               │            │ conv2d_94[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        448 │ add_52[0][0]      │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ add_53[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ...
# │ add_113 (Add)       │ (None, 8, 8, 32)  │          0 │ conv2d_185[0][0], │
# │                     │                   │            │ conv2d_186[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        896 │ add_112[0][0]     │
# │ (BatchNormalizatio… │ 224)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 32)  │        128 │ add_113[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_65 (ReLU)     │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, 8, 8, 896) │     28,672 │ re_lu_65[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 8, 8, 224) │          0 │ re_lu_65[0][0]    │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_187 (Conv2D) │ (None, 16, 16,    │    200,704 │ re_lu_65[0][0]    │
# │                     │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_46    │ (None, 16, 16,    │          0 │ conv2d_188[0][0]  │
# │ (UpSampling2D)      │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, 8, 8, 128) │      4,096 │ re_lu_65[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, 8, 8, 128) │     28,672 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_114 (Add)       │ (None, 16, 16,    │          0 │ conv2d_187[0][0], │
# │                     │ 896)              │            │ up_sampling2d_46… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_115 (Add)       │ (None, 8, 8, 128) │          0 │ conv2d_189[0][0], │
# │                     │                   │            │ conv2d_190[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      3,584 │ add_114[0][0]     │
# │ (BatchNormalizatio… │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ add_115[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_116 (Add)       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 896)              │            │ re_lu_62[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_117 (Add)       │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ re_lu_63[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_67 (ReLU)     │ (None, 16, 16,    │          0 │ add_116[0][0]     │
# │                     │ 896)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_68 (ReLU)     │ (None, 8, 8, 128) │          0 │ add_117[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, 8, 8, 448) │     57,344 │ re_lu_68[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 8, 8, 896) │          0 │ re_lu_67[0][0]    │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, 16, 16,    │    401,408 │ re_lu_67[0][0]    │
# │                     │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_47    │ (None, 16, 16,    │          0 │ conv2d_192[0][0]  │
# │ (UpSampling2D)      │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, 8, 8, 64)  │      8,192 │ re_lu_68[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, 8, 8, 64)  │     57,344 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_118 (Add)       │ (None, 16, 16,    │          0 │ conv2d_191[0][0], │
# │                     │ 448)              │            │ up_sampling2d_47… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_119 (Add)       │ (None, 8, 8, 64)  │          0 │ conv2d_193[0][0], │
# │                     │                   │            │ conv2d_194[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,792 │ add_118[0][0]     │
# │ (BatchNormalizatio… │ 448)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ add_119[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_69 (ReLU)     │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 4, 4, 448) │          0 │ re_lu_69[0][0],   │
# │ (AveragePooling2D)  │                   │            │ re_lu_69[1][0],   │
# │                     │                   │            │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 4, 4, 448) │    258,048 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, 8, 8, 448) │  1,806,336 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_48    │ (None, 8, 8, 448) │          0 │ conv2d_196[0][0]  │
# │ (UpSampling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 4, 4, 64)  │     36,864 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, 4, 4, 64)  │    258,048 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_120 (Add)       │ (None, 8, 8, 448) │          0 │ conv2d_195[0][0], │
# │                     │                   │            │ up_sampling2d_48… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_121 (Add)       │ (None, 4, 4, 64)  │          0 │ conv2d_197[0][0], │
# │                     │                   │            │ conv2d_198[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 448) │      1,792 │ add_120[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 64)  │        256 │ add_121[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_70 (ReLU)     │ (None, 4, 4, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 4, 4, 128) │          0 │ re_lu_67[0][0],   │
# │ (AveragePooling2D)  │                   │            │ re_lu_68[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_200 (Conv2D) │ (None, 4, 4,      │    131,072 │ re_lu_70[1][0]    │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_202 (Conv2D) │ (None, 4, 4,      │    262,144 │ average_pooling2… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, 8, 8,      │    917,504 │ re_lu_70[0][0]    │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_49    │ (None, 8, 8,      │          0 │ conv2d_200[0][0]  │
# │ (UpSampling2D)      │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_201 (Conv2D) │ (None, 8, 8,      │  1,835,008 │ average_pooling2… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_50    │ (None, 8, 8,      │          0 │ conv2d_202[0][0]  │
# │ (UpSampling2D)      │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_122 (Add)       │ (None, 8, 8,      │          0 │ conv2d_199[0][0], │
# │                     │ 2048)             │            │ up_sampling2d_49… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_123 (Add)       │ (None, 8, 8,      │          0 │ conv2d_201[0][0], │
# │                     │ 2048)             │            │ up_sampling2d_50… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      8,192 │ add_122[0][0]     │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      8,192 │ add_123[0][0]     │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_124 (Add)       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_71 (ReLU)     │ (None, 8, 8,      │          0 │ add_124[0][0]     │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, 8, 8, 512) │  1,048,576 │ re_lu_71[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_203[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_204 (Conv2D) │ (None, 8, 8, 512) │  2,359,296 │ re_lu_72[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_204[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_205 (Conv2D) │ (None, 8, 8,      │  1,048,576 │ re_lu_73[0][0]    │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      8,192 │ conv2d_205[0][0]  │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_125 (Add)       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ re_lu_71[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 8, 8,      │          0 │ add_125[0][0]     │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, 8, 8, 512) │  1,048,576 │ re_lu_74[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_206[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, 8, 8, 512) │  2,359,296 │ re_lu_75[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_207[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, 8, 8,      │  1,048,576 │ re_lu_76[0][0]    │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      8,192 │ conv2d_208[0][0]  │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_126 (Add)       │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ re_lu_74[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 8, 8,      │          0 │ add_126[0][0]     │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ re_lu_77[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc (Dense)          │ (None, 1000)      │  2,049,000 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 25,610,152 (97.69 MB)
#  Trainable params: 25,557,032 (97.49 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
import cv2
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
#Matplot Images
import matplotlib.image as mpimg
# Tensflor and Keras Layer and Model and Optimize and Loss
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import *
from tensorflow.keras.losses import BinaryCrossentropy
#PreTrained Model
from tensorflow.keras.applications import *
#Image Generator DataAugmentation
#Early Stopping
from tensorflow.keras.callbacks import EarlyStopping
# Warnings Remove 
import warnings 
warnings.filterwarnings("ignore")
#Splitting Data 
# import splitfolders
from tensorflow.keras.preprocessing import image_dataset_from_directory
import random
from sklearn.cluster import KMeans
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image

# %%
directory = "/kaggle/input/paddydoctormedium"

filepath =[]
label = []

folds = os.listdir(directory)

for fold in folds:
    f_path = os.path.join(directory , fold)
    
    imgs = os.listdir(f_path)
    
    for img in imgs:
        
        img_path = os.path.join(f_path , img)
        filepath.append(img_path)
        label.append(fold)
        
#Concat data paths with labels
file_path_series = pd.Series(filepath , name= 'filepath')
Label_path_series = pd.Series(label , name = 'label')
df_train = pd.concat([file_path_series ,Label_path_series ] , axis = 1)

# %%
from sklearn. model_selection import train_test_split
train_df , val_df = train_test_split(df_train ,train_size = 0.9 , shuffle = True ,random_state = 42 )

# %%
data_dir = '/kaggle/input/paddydoctormedium'

print('Training Images:')
# creating the training dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(256, 256),
    batch_size=32)

#Testing Augmented Data
print('Validation Images:')
validation_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir, 
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(256, 256),
    batch_size=32)
# Out:
# Training Images:
# Found 16225 files belonging to 13 classes.
# Using 12980 files for training.
# Validation Images:
# Found 16225 files belonging to 13 classes.
# Using 3245 files for validation.

# %%
train_ds = train_ds.map(lambda x, y: (x / 255.0, y))
# Val Data
validation_ds = validation_ds.map(lambda x, y: (x / 255.0, y))

# %%
model = OctaveResNet101(include_top=True,
                        weights=None,
                        input_tensor=None,
                        input_shape=(256, 256, 3),
                        pooling='avg',
                        classes=13,
                        alpha=0.125,
                        expansion=4,
                        initial_filters=64,
                        initial_strides=True)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(
    patience=10, 
    restore_best_weights=True,
)

# Train the model 
history = model.fit(train_ds,
                    epochs=25,
                    validation_data=validation_ds,
                    callbacks=early_stopping)
# Out:
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710735678.488198     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710735678.906492     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 405/406 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.2868 - loss: 2.5653
# W0000 00:00:1710736125.031519     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2870 - loss: 2.5641
# W0000 00:00:1710736147.272556     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710736186.449760     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 827s 1s/step - accuracy: 0.2872 - loss: 2.5628 - val_accuracy: 0.3399 - val_loss: 2.2867
# Epoch 2/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 726ms/step - accuracy: 0.5090 - loss: 1.5033 - val_accuracy: 0.4311 - val_loss: 2.2518
# Epoch 3/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 296s 727ms/step - accuracy: 0.6492 - loss: 1.0833 - val_accuracy: 0.5319 - val_loss: 1.6206
# Epoch 4/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 297s 730ms/step - accuracy: 0.7293 - loss: 0.8217 - val_accuracy: 0.5470 - val_loss: 3.4347
# Epoch 5/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 726ms/step - accuracy: 0.7872 - loss: 0.6631 - val_accuracy: 0.5593 - val_loss: 1.8800
# Epoch 6/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 726ms/step - accuracy: 0.8316 - loss: 0.5269 - val_accuracy: 0.5562 - val_loss: 2.6739
# Epoch 7/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 727ms/step - accuracy: 0.8420 - loss: 0.4836 - val_accuracy: 0.7867 - val_loss: 0.7086
# Epoch 8/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 724ms/step - accuracy: 0.8917 - loss: 0.3391 - val_accuracy: 0.7445 - val_loss: 0.8563
# Epoch 9/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 725ms/step - accuracy: 0.9079 - loss: 0.3030 - val_accuracy: 0.4508 - val_loss: 3.6376
# Epoch 10/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 296s 728ms/step - accuracy: 0.9272 - loss: 0.2349 - val_accuracy: 0.6875 - val_loss: 1.2012
# Epoch 11/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 725ms/step - accuracy: 0.9319 - loss: 0.2064 - val_accuracy: 0.7331 - val_loss: 1.9238
# Epoch 12/25
# 142/406 ━━━━━━━━━━━━━━━━━━━━ 2:57 672ms/step - accuracy: 0.9303 - loss: 0.2013
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 727ms/step - accuracy: 0.9579 - loss: 0.1263 - val_accuracy: 0.7664 - val_loss: 0.8794
# Epoch 16/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9603 - loss: 0.1194 - val_accuracy: 0.8653 - val_loss: 0.5125
# Epoch 17/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9602 - loss: 0.1231 - val_accuracy: 0.4154 - val_loss: 3.7846
# Epoch 18/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9587 - loss: 0.1362 - val_accuracy: 0.8373 - val_loss: 0.7721
# Epoch 19/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9618 - loss: 0.1168 - val_accuracy: 0.8166 - val_loss: 0.7907
# Epoch 20/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9704 - loss: 0.1018 - val_accuracy: 0.8888 - val_loss: 0.4944
# Epoch 21/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 295s 726ms/step - accuracy: 0.9733 - loss: 0.0824 - val_accuracy: 0.8675 - val_loss: 0.5047
# Epoch 22/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9721 - loss: 0.0925 - val_accuracy: 0.9193 - val_loss: 0.3004
# Epoch 23/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 293s 722ms/step - accuracy: 0.9731 - loss: 0.0892 - val_accuracy: 0.7485 - val_loss: 1.2166
# Epoch 24/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 294s 723ms/step - accuracy: 0.9717 - loss: 0.0819 - val_accuracy: 0.9405 - val_loss: 0.2238
# Epoch 25/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 293s 720ms/step - accuracy: 0.9846 - loss: 0.0502 - val_accuracy: 0.6379 - val_loss: 2.9087

# %%
validation_loss, validation_accuracy = model.evaluate(validation_ds)

# Print the validation loss and accuracy
print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 validation_loss, validation_accuracy = model.evaluate(validation_ds)
#       3 # Print the validation loss and accuracy
#       4 print("Validation Loss:", validation_loss)
#
# NameError: name 'model' is not defined

# %%
model.save('model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.save('model')
#
# NameError: name 'model' is not defined

# %%
model2 = OctaveResNet50(include_top=True,
                        weights=None,
                        input_tensor=None,
                        input_shape=(256, 256, 3),
                        pooling='avg',
                        classes=13,
                        alpha=0.125,
                        expansion=4,
                        initial_filters=64,
                        initial_strides=True)
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(
    patience=10, 
    restore_best_weights=True,
)

# Train the model 
history = model2.fit(train_ds,
                    epochs=25,
                    validation_data=validation_ds,
                    callbacks=early_stopping)
# Out:
# Epoch 1/25
# W0000 00:00:1710743396.268931     110 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 405/406 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.3209 - loss: 2.4297
# W0000 00:00:1710743606.842568     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.3211 - loss: 2.4285
# W0000 00:00:1710743617.987575     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710743634.822261     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 356s 589ms/step - accuracy: 0.3213 - loss: 2.4273 - val_accuracy: 0.1639 - val_loss: 14.1378
# Epoch 2/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 174s 427ms/step - accuracy: 0.5830 - loss: 1.2780 - val_accuracy: 0.3267 - val_loss: 3.4023
# Epoch 3/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.7134 - loss: 0.9060 - val_accuracy: 0.5824 - val_loss: 1.3037
# Epoch 4/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.7814 - loss: 0.6670 - val_accuracy: 0.6080 - val_loss: 1.4517
# Epoch 5/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.8309 - loss: 0.5188 - val_accuracy: 0.7519 - val_loss: 0.8579
# Epoch 6/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.8657 - loss: 0.4070 - val_accuracy: 0.7205 - val_loss: 1.0600
# Epoch 7/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.8897 - loss: 0.3338 - val_accuracy: 0.7254 - val_loss: 1.1231
# Epoch 8/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.9117 - loss: 0.2622 - val_accuracy: 0.8247 - val_loss: 0.6164
# Epoch 9/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.9287 - loss: 0.2140 - val_accuracy: 0.7886 - val_loss: 0.7018
# Epoch 10/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 426ms/step - accuracy: 0.9432 - loss: 0.1798 - val_accuracy: 0.8404 - val_loss: 0.5802
# Epoch 11/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9386 - loss: 0.1864 - val_accuracy: 0.8706 - val_loss: 0.5010
# Epoch 12/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9527 - loss: 0.1465 - val_accuracy: 0.8764 - val_loss: 0.4010
# Epoch 13/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9576 - loss: 0.1248 - val_accuracy: 0.7732 - val_loss: 0.9720
# Epoch 14/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9629 - loss: 0.1215 - val_accuracy: 0.8622 - val_loss: 0.5626
# Epoch 15/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9610 - loss: 0.1138 - val_accuracy: 0.8561 - val_loss: 0.5350
# Epoch 16/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9600 - loss: 0.1239 - val_accuracy: 0.7840 - val_loss: 0.9566
# Epoch 17/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9665 - loss: 0.1013 - val_accuracy: 0.8173 - val_loss: 0.7598
# Epoch 18/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9739 - loss: 0.0816 - val_accuracy: 0.9131 - val_loss: 0.3283
# Epoch 19/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9726 - loss: 0.0867 - val_accuracy: 0.9156 - val_loss: 0.3191
# Epoch 20/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 424ms/step - accuracy: 0.9733 - loss: 0.0849 - val_accuracy: 0.9057 - val_loss: 0.3642
# Epoch 21/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9719 - loss: 0.0865 - val_accuracy: 0.8194 - val_loss: 0.8306
# Epoch 22/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 425ms/step - accuracy: 0.9793 - loss: 0.0666 - val_accuracy: 0.9196 - val_loss: 0.2995
# Epoch 23/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 424ms/step - accuracy: 0.9822 - loss: 0.0570 - val_accuracy: 0.8518 - val_loss: 0.6663
# Epoch 24/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 173s 424ms/step - accuracy: 0.9811 - loss: 0.0573 - val_accuracy: 0.9048 - val_loss: 0.3955
# Epoch 25/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 172s 424ms/step - accuracy: 0.9836 - loss: 0.0564 - val_accuracy: 0.9069 - val_loss: 0.3266

# %%
validation_loss, validation_accuracy = model2.evaluate(validation_ds)

# Print the validation loss and accuracy
print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - accuracy: 0.9218 - loss: 0.3085
# Validation Loss: 0.29854533076286316
# Validation Accuracy: 0.9195685386657715

# %%
model3 = OctaveResNet152(include_top=True,
                        weights=None,
                        input_tensor=None,
                        input_shape=(256, 256, 3),
                        pooling='avg',
                        classes=13,
                        alpha=0.125,
                        expansion=4,
                        initial_filters=64,
                        initial_strides=True)
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(
    patience=10, 
    restore_best_weights=True,
)

# Train the model 
history = model3.fit(train_ds,
                    epochs=25,
                    validation_data=validation_ds,
                    callbacks=early_stopping)
# Out:
# Epoch 1/25
# W0000 00:00:1710748335.377857     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 405/406 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.2816 - loss: 2.4382
# W0000 00:00:1710749051.342380     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2818 - loss: 2.4372
# W0000 00:00:1710749084.162305     108 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710749127.903101     111 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 1324s 2s/step - accuracy: 0.2820 - loss: 2.4361 - val_accuracy: 0.2179 - val_loss: 2.9655
# Epoch 2/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 428s 1s/step - accuracy: 0.5070 - loss: 1.4917 - val_accuracy: 0.3584 - val_loss: 2.4477
# Epoch 3/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 427s 1s/step - accuracy: 0.6220 - loss: 1.1659 - val_accuracy: 0.4456 - val_loss: 1.9637
# Epoch 4/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 430s 1s/step - accuracy: 0.7109 - loss: 0.9053 - val_accuracy: 0.6419 - val_loss: 1.1784
# Epoch 5/25
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.7823 - loss: 0.6873 - val_accuracy: 0.4826 - val_loss: 2.4930
# Epoch 6/25
# 254/406 ━━━━━━━━━━━━━━━━━━━━ 2:28 975ms/step - accuracy: 0.8113 - loss: 0.5873

# %%
validation_loss, validation_accuracy = model3.evaluate(validation_ds)

# Print the validation loss and accuracy
print("Validation Loss:", validation_loss)
print("Validation Accuracy:", validation_accuracy)
